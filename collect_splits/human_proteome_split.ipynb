# %%
from pathlib import Path
from tempfile import TemporaryDirectory

# You may need to install pandas and sklearn
from pandas import read_csv
from sklearn.model_selection import train_test_split

# %%
data_path = Path('') / '..' / 'data'
sequence_file = data_path / "sequences.fasta"
output_file = data_path / "mmseqs_output"

# Get the path in string form: this will be useful for bash-type commands!
sequence_file_path = str(sequence_file)
output_file_path = str(output_file)

# %%
# Download human sequences into the "sequence.fasta" file. You could pick other sequences, too!
# !curl "https://www.uniprot.org/uniprot/?query=reviewed:yes%20AND%20organism:%22Homo%20sapiens%20(Human)%20[9606]%22&format=fasta&force=true&sort=score" -o {sequence_file_path}

# %%
# Make sure you have mmseqs2 installed
# !conda install -c conda-forge -c bioconda mmseqs2

# %%
# This sets the identity thershold (in cd-hit, the "-n" option).
# A value of 0.2 means that sequences sharing a similarity of 20% or more will be placed in the same cluster
# Clusters are non-overlapping, aka: sequences that would belong in two clusters will be assigned to one, regardless
cluster_identity = 0.2

# We need a temporary directory to store artifacts from mmseqs, which can be discarted after the computation is finished
with TemporaryDirectory() as temp_dir:
    # !mmseqs easy-cluster --min-seq-id {cluster_identity} {sequence_file_path} {output_file_path} {temp_dir}
# Out:
# easy-cluster --min-seq-id 0.2 ../data/sequences.fasta ../data/output.fasta /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4
#
# MMseqs Version:                     	13.45111
# Substitution matrix                 	nucl:nucleotide.out,aa:blosum62.out
# Seed substitution matrix            	nucl:nucleotide.out,aa:VTML80.out
# Sensitivity                         	4
# k-mer length                        	0
# k-score                             	2147483647
# Alphabet size                       	nucl:5,aa:21
# Max sequence length                 	65535
# Max results per query               	20
# Split database                      	0
# Split mode                          	2
# Split memory limit                  	0
# Coverage threshold                  	0.8
# Coverage mode                       	0
# Compositional bias                  	1
# Diagonal scoring                    	true
# Exact k-mer matching                	0
# Mask residues                       	1
# Mask lower case residues            	0
# Minimum diagonal score              	15
# Include identical seq. id.          	false
# Spaced k-mers                       	1
# Preload mode                        	0
# Pseudo count a                      	1
# Pseudo count b                      	1.5
# Spaced k-mer pattern
# Local temporary path
# Threads                             	8
# Compressed                          	0
# Verbosity                           	3
# Add backtrace                       	false
# Alignment mode                      	3
# Alignment mode                      	0
# Allow wrapped scoring               	false
# E-value threshold                   	0.001
# Seq. id. threshold                  	0.2
# Min alignment length                	0
# Seq. id. mode                       	0
# Alternative alignments              	0
# Max reject                          	2147483647
# Max accept                          	2147483647
# Score bias                          	0
# Realign hits                        	false
# Realign score bias                  	-0.2
# Realign max seqs                    	2147483647
# Gap open cost                       	nucl:5,aa:11
# Gap extension cost                  	nucl:2,aa:1
# Zdrop                               	40
# Rescore mode                        	0
# Remove hits by seq. id. and coverage	false
# Sort results                        	0
# Cluster mode                        	0
# Max connected component depth       	1000
# Similarity type                     	2
# Single step clustering              	false
# Cascaded clustering steps           	3
# Cluster reassign                    	false
# Remove temporary files              	true
# Force restart with latest tmp       	false
# MPI runner
# k-mers per sequence                 	21
# Scale k-mers per sequence           	nucl:0.200,aa:0.000
# Adjust k-mer length                 	false
# Shift hash                          	67
# Include only extendable             	false
# Skip repeating k-mers               	false
# Database type                       	0
# Shuffle input database              	true
# Createdb mode                       	1
# Write lookup file                   	0
# Offset of numeric ids               	0
#
# createdb ../data/sequences.fasta /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input --dbtype 0 --shuffle 1 --createdb-mode 1 --write-lookup 0 --id-offset 0 --compressed 0 -v 3
#
# Shuffle database cannot be combined with --createdb-mode 0
# We recompute with --shuffle 0
# Converting sequences
# Multiline fasta can not be combined with --createdb-mode 0
# We recompute with --createdb-mode 1
# Time for merging to input_h: 0h 0m 0s 0ms
# Time for merging to input: 0h 0m 0s 0ms
# [20302] 0s 48ms
# Time for merging to input_h: 0h 0m 0s 0ms
# Time for merging to input: 0h 0m 0s 0ms
# Database type: Aminoacid
# Time for processing: 0h 0m 0s 59ms
# Create directory /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp
# cluster /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp --max-seqs 20 -c 0.8 --spaced-kmer-mode 1 --alignment-mode 3 -e 0.001 --min-seq-id 0.2 --remove-tmp-files 1
#
# Set cluster sensitivity to -s 6.000000
# Set cluster mode SET COVER
# Set cluster iterations to 3
# linclust /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/clu_redundancy /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3 --sub-mat nucl:nucleotide.out,aa:blosum62.out -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.2 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca 1 --pcb 1.5 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --gap-open nucl:5,aa:11 --gap-extend nucl:2,aa:1 --zdrop 40 --alph-size nucl:5,aa:13 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale nucl:0.200,aa:0.000 --adjust-kmer-len 0 --mask 0 --mask-lower-case 0 -k 0 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --rescore-mode 0 --filter-hits 0 --sort-results 0 --remove-tmp-files 1 --force-reuse 0
#
# kmermatcher /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pref --sub-mat nucl:nucleotide.out,aa:blosum62.out --alph-size nucl:5,aa:13 --min-seq-id 0.2 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale nucl:0.200,aa:0.000 --adjust-kmer-len 0 --mask 0 --mask-lower-case 0 --cov-mode 0 -k 0 -c 0.8 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 8 --compressed 0 -v 3
#
# kmermatcher /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pref --sub-mat nucl:nucleotide.out,aa:blosum62.out --alph-size nucl:5,aa:13 --min-seq-id 0.2 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale nucl:0.200,aa:0.000 --adjust-kmer-len 0 --mask 0 --mask-lower-case 0 --cov-mode 0 -k 0 -c 0.8 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 8 --compressed 0 -v 3
#
# Database size: 20386 type: Aminoacid
# Reduced amino acid alphabet: (A S T) (C) (D B N) (E Q Z) (F Y) (G) (H) (I V) (K R) (L J M) (P) (W) (X)
#
# Generate k-mers list for 1 split
# [=================================================================] 100.00% 20.39K 0s 135ms
# Sort kmer 0h 0m 0s 15ms
# Sort by rep. sequence 0h 0m 0s 3ms
# Time for fill: 0h 0m 0s 3ms
# Time for merging to pref: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 189ms
# rescorediagonal /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pref /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pref_rescore1 --sub-mat nucl:nucleotide.out,aa:blosum62.out --rescore-mode 0 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.8 -a 0 --cov-mode 0 --min-seq-id 0.5 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 8 --compressed 0 -v 3
# [=================================================================] 100.00% 20.39K 0s 18ms
# Time for merging to pref_rescore1: 0h 0m 0s 16ms
# Time for processing: 0h 0m 0s 55ms
# clust /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pref_rescore1 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pre_clust --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3
# Clustering mode: Set Cover
# [=================================================================] 100.00% 20.39K 0s 13ms
# Sort entries
# Find missing connections
# Found 3726 new connections.
# Reconstruct initial order
# [=================================================================] 100.00% 20.39K 0s 13ms
# Add missing connections
# [=================================================================] 100.00% 20.39K 0s 1ms
#
# Time for read in: 0h 0m 0s 37ms
# Total time: 0h 0m 0s 41ms
#
# Size of the sequence database: 20386
# Size of the alignment database: 20386
# Number of clusters: 18056
#
# Writing results 0h 0m 0s 7ms
# Time for merging to pre_clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 60ms
# createsubdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/order_redundancy /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 12ms
# createsubdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/order_redundancy /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pref /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pref_filter1 -v 3 --subdb-mode 1
#
# Time for merging to pref_filter1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 16ms
# filterdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pref_filter1 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pref_filter2 --filter-file /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/order_redundancy --threads 8 --compressed 0 -v 3
#
# Filtering using file(s)
# [=================================================================] 100.00% 18.06K 0s 14ms
# Time for merging to pref_filter2: 0h 0m 0s 13ms
# Time for processing: 0h 0m 0s 62ms
# rescorediagonal /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/input_step_redundancy /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/input_step_redundancy /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pref_filter2 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pref_rescore2 --sub-mat nucl:nucleotide.out,aa:blosum62.out --rescore-mode 1 --wrapped-scoring 0 --filter-hits 1 -e 0.001 -c 0.8 -a 0 --cov-mode 0 --min-seq-id 0.2 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 8 --compressed 0 -v 3
#
# Can not find any score per column for coverage 0.800000 and sequence identity 0.200000. No hit will be filtered.
# [=================================================================] 100.00% 18.06K 0s 17ms
# Time for merging to pref_rescore2: 0h 0m 0s 12ms
# Time for processing: 0h 0m 0s 56ms
# align /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/input_step_redundancy /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/input_step_redundancy /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pref_rescore2 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/aln --sub-mat nucl:nucleotide.out,aa:blosum62.out -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.2 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca 1 --pcb 1.5 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --gap-open nucl:5,aa:11 --gap-extend nucl:2,aa:1 --zdrop 40 --threads 8 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 18056 type: Aminoacid
# Target database size: 18056 type: Aminoacid
# Calculation of alignments
# [=================================================================] 100.00% 18.06K 2s 104ms
# Time for merging to aln: 0h 0m 0s 11ms
# 21602 alignments calculated
# 20515 sequence pairs passed the thresholds (0.949681 of overall calculated)
# 1.136187 hits per query sequence
# Time for processing: 0h 0m 2s 142ms
# clust /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/input_step_redundancy /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/aln /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/clust --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3
#
# Clustering mode: Set Cover
# [=================================================================] 100.00% 18.06K 0s 12ms
# Sort entries
# Find missing connections
# Found 2459 new connections.
# Reconstruct initial order
# [=================================================================] 100.00% 18.06K 0s 12ms
# Add missing connections
# [=================================================================] 100.00% 18.06K 0s 1ms
#
# Time for read in: 0h 0m 0s 30ms
# Total time: 0h 0m 0s 33ms
#
# Size of the sequence database: 18056
# Size of the alignment database: 18056
# Number of clusters: 16075
#
# Writing results 0h 0m 0s 6ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 51ms
# mergeclusters /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/clu_redundancy /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pre_clust /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/clust --threads 8 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 100.00% 18.06K 0s 12ms
# Clustering step 2
# [=================================================================] 100.00% 16.08K 0s 24ms
# Write merged clustering
# [=================================================================] 100.00% 20.39K 0s 43ms      eta 0s
# Time for merging to clu_redundancy: 0h 0m 0s 13ms
# Time for processing: 0h 0m 0s 72ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pref_filter1 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pref -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pref_rescore1 -v 3
#
# Time for processing: 0h 0m 0s 2ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pre_clust -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/input_step_redundancy -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/input_step_redundancy_h -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pref_filter2 -v 3
#
# Time for processing: 0h 0m 0s 2ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/pref_rescore2 -v 3
#
# Time for processing: 0h 0m 0s 2ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/aln -v 3
#
# Time for processing: 0h 0m 0s 2ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/linclust/12401491964587586795/clust -v 3
#
# Time for processing: 0h 0m 0s 1ms
# createsubdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/clu_redundancy /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 9ms
# prefilter /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step_redundancy /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step_redundancy /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/pref_step0 --sub-mat nucl:nucleotide.out,aa:blosum62.out --seed-sub-mat nucl:nucleotide.out,aa:VTML80.out -s 1 -k 0 --k-score 2147483647 --alph-size nucl:5,aa:21 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.8 --cov-mode 0 --comp-bias-corr 0 --diag-score 0 --exact-kmer-matching 0 --mask 1 --mask-lower-case 0 --min-ungapped-score 0 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca 1 --pcb 1.5 --threads 8 --compressed 0 -v 3
#
# Query database size: 16075 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 16075 type: Aminoacid
# Index table k-mer threshold: 154 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 100.00% 16.08K 0s 397ms
# Index table: Masked residues: 396108
# Index table: fill
# [=================================================================] 100.00% 16.08K 0s 229ms
# Index statistics
# Entries:          4111794
# DB size:          511 MB
# Avg k-mer size:   0.064247
# Top 10 k-mers
#     QRLRML	53
#     LYDMNY	53
#     CGPYPE	40
#     PMFLLS	38
#     TFDAFT	31
#     QVIFRR	29
#     LDARYR	29
#     LHPYLS	28
#     VHSGRT	27
#     TPLPYS	25
# Time for index table init: 0h 0m 1s 254ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 154
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 16075
# Target db start 1 to 16075
# [=================================================================] 100.00% 16.08K 0s 558ms
#
# 2.608414 k-mers per position
# 472 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 4 sequences passed prefiltering per query sequence
# 2 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step0: 0h 0m 0s 12ms
# Time for processing: 0h 0m 2s 593ms
# align /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step_redundancy /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step_redundancy /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/pref_step0 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/aln_step0 --sub-mat nucl:nucleotide.out,aa:blosum62.out -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.2 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 0 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca 1 --pcb 1.5 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --gap-open nucl:5,aa:11 --gap-extend nucl:2,aa:1 --zdrop 40 --threads 8 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 16075 type: Aminoacid
# Target database size: 16075 type: Aminoacid
# Calculation of alignments
# [=================================================================] 100.00% 16.08K 4s 382ms
# Time for merging to aln_step0: 0h 0m 0s 11ms
# 37593 alignments calculated
# 26254 sequence pairs passed the thresholds (0.698375 of overall calculated)
# 1.633219 hits per query sequence
# Time for processing: 0h 0m 4s 418ms
# clust /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step_redundancy /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/aln_step0 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/clu_step0 --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3
#
# Clustering mode: Set Cover
# [=================================================================] 100.00% 16.08K 0s 11ms
# Sort entries
# Find missing connections
# Found 1247 new connections.
# Reconstruct initial order
# [=================================================================] 100.00% 16.08K 0s 12ms
# Add missing connections
# [=================================================================] 100.00% 16.08K 0s 1ms
#
# Time for read in: 0h 0m 0s 28ms
# Total time: 0h 0m 0s 30ms
#
# Size of the sequence database: 16075
# Size of the alignment database: 16075
# Number of clusters: 13388
#
# Writing results 0h 0m 0s 5ms
# Time for merging to clu_step0: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 43ms
# createsubdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/clu_step0 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step_redundancy /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step1 -v 3 --subdb-mode 1
#
# Time for merging to input_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 8ms
# prefilter /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step1 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step1 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/pref_step1 --sub-mat nucl:nucleotide.out,aa:blosum62.out --seed-sub-mat nucl:nucleotide.out,aa:VTML80.out -s 3.5 -k 0 --k-score 2147483647 --alph-size nucl:5,aa:21 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.8 --cov-mode 0 --comp-bias-corr 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca 1 --pcb 1.5 --threads 8 --compressed 0 -v 3
#
# Query database size: 13388 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 13388 type: Aminoacid
# Index table k-mer threshold: 131 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 100.00% 13.39K 0s 331ms
# Index table: Masked residues: 296180
# Index table: fill
# [=================================================================] 100.00% 13.39K 0s 298ms
# Index statistics
# Entries:          6679407
# DB size:          526 MB
# Avg k-mer size:   0.104366
# Top 10 k-mers
#     IHDKNI	38
#     LLGPGK	32
#     LLPLLL	28
#     VHSGRT	23
#     SSPSSS	22
#     GSDTLW	20
#     LGGFVY	20
#     QVIFRR	17
#     REELQL	16
#     IVRLEN	16
# Time for index table init: 0h 0m 1s 216ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 131
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 13388
# Target db start 1 to 13388
# [=================================================================] 100.00% 13.39K 3s 902ms
#
# 40.098489 k-mers per position
# 2128 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 10 sequences passed prefiltering per query sequence
# 9 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step1: 0h 0m 0s 12ms
# Time for processing: 0h 0m 5s 872ms
# align /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step1 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step1 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/pref_step1 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/aln_step1 --sub-mat nucl:nucleotide.out,aa:blosum62.out -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.2 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca 1 --pcb 1.5 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --gap-open nucl:5,aa:11 --gap-extend nucl:2,aa:1 --zdrop 40 --threads 8 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 13388 type: Aminoacid
# Target database size: 13388 type: Aminoacid
# Calculation of alignments
# [=================================================================] 100.00% 13.39K 1s 686ms
# Time for merging to aln_step1: 0h 0m 0s 11ms
# 40646 alignments calculated
# 14986 sequence pairs passed the thresholds (0.368696 of overall calculated)
# 1.119361 hits per query sequence
# Time for processing: 0h 0m 1s 720ms
# clust /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step1 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/aln_step1 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/clu_step1 --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3
#
# Clustering mode: Set Cover
# [=================================================================] 100.00% 13.39K 0s 12ms              ] 29.45% 3.94K eta 0s
# Sort entries
# Find missing connections
# Found 334 new connections.
# Reconstruct initial order
# [=================================================================] 100.00% 13.39K 0s 12ms
# Add missing connections
# [=================================================================] 100.00% 13.39K 0s 1ms
#
# Time for read in: 0h 0m 0s 29ms
# Total time: 0h 0m 0s 31ms
#
# Size of the sequence database: 13388
# Size of the alignment database: 13388
# Number of clusters: 12708
#
# Writing results 0h 0m 0s 4ms
# Time for merging to clu_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 42ms
# createsubdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/clu_step1 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step1 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step2 -v 3 --subdb-mode 1
#
# Time for merging to input_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 8ms
# prefilter /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step2 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step2 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/pref_step2 --sub-mat nucl:nucleotide.out,aa:blosum62.out --seed-sub-mat nucl:nucleotide.out,aa:VTML80.out -s 6 -k 0 --k-score 2147483647 --alph-size nucl:5,aa:21 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.8 --cov-mode 0 --comp-bias-corr 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca 1 --pcb 1.5 --threads 8 --compressed 0 -v 3
#
# Query database size: 12708 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 12708 type: Aminoacid
# Index table k-mer threshold: 109 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 100.00% 12.71K 0s 308ms
# Index table: Masked residues: 279033
# Index table: fill
# [=================================================================] 100.00% 12.71K 0s 373ms
# Index statistics
# Entries:          6550675
# DB size:          525 MB
# Avg k-mer size:   0.102354
# Top 10 k-mers
#     LLLLLL	55
#     SSSSSS	45
#     ALLLLL	30
#     LLSLLL	27
#     SSSLSS	24
#     LLALLL	22
#     LLGLLL	22
#     LPLLLL	22
#     LLLLSL	22
#     SSPSSS	22
# Time for index table init: 0h 0m 1s 295ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 109
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 12708
# Target db start 1 to 12708
# [=================================================================] 100.00% 12.71K 32s 26ms
#
# 422.181531 k-mers per position
# 20857 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 19 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step2: 0h 0m 0s 11ms
# Time for processing: 0h 0m 34s 143ms
# align /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step2 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step2 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/pref_step2 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/aln_step2 --sub-mat nucl:nucleotide.out,aa:blosum62.out -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.2 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.8 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca 1 --pcb 1.5 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --gap-open nucl:5,aa:11 --gap-extend nucl:2,aa:1 --zdrop 40 --threads 8 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 12708 type: Aminoacid
# Target database size: 12708 type: Aminoacid
# Calculation of alignments
# [=================================================================] 100.00% 12.71K 1s 599ms
# Time for merging to aln_step2: 0h 0m 0s 10ms
# 54079 alignments calculated
# 13155 sequence pairs passed the thresholds (0.243255 of overall calculated)
# 1.035175 hits per query sequence
# Time for processing: 0h 0m 1s 632ms
# clust /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step2 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/aln_step2 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/clu_step2 --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3
#
# Clustering mode: Set Cover
# [=================================================================] 100.00% 12.71K 0s 11ms
# Sort entries
# Find missing connections
# Found 121 new connections.
# Reconstruct initial order
# [=================================================================] 100.00% 12.71K 0s 11ms
# Add missing connections
# [=================================================================] 100.00% 12.71K 0s 1ms
#
# Time for read in: 0h 0m 0s 26ms
# Total time: 0h 0m 0s 28ms
#
# Size of the sequence database: 12708
# Size of the alignment database: 12708
# Number of clusters: 12460
#
# Writing results 0h 0m 0s 4ms
# Time for merging to clu_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 39ms
# mergeclusters /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/clu_redundancy /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/clu_step0 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/clu_step1 /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/clu_step2 --threads 8 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 100.00% 16.08K 0s 11ms
# Clustering step 2
# [=================================================================] 100.00% 13.39K 0s 23ms
# Clustering step 3
# [=================================================================] 100.00% 12.71K 0s 38ms
# Clustering step 4
# [=================================================================] 100.00% 12.46K 0s 48ms
# Write merged clustering
# [=================================================================] 100.00% 20.39K 0s 60ms
# Time for merging to clu: 0h 0m 0s 8ms
# Time for processing: 0h 0m 0s 82ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/clu_redundancy -v 3
#
# Time for processing: 0h 0m 0s 2ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step_redundancy -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step_redundancy_h -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/pref_step0 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/aln_step0 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/clu_step0 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/pref_step1 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/aln_step1 -v 3
#
# Time for processing: 0h 0m 0s 2ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/clu_step1 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/pref_step2 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/aln_step2 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/clu_step2 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step1 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step1_h -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step2 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_tmp/10527061271244589406/input_step2_h -v 3
#
# Time for processing: 0h 0m 0s 1ms
# createtsv /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/cluster.tsv --threads 8 -v 3
#
# Time for merging to cluster.tsv: 0h 0m 0s 10ms
# Time for processing: 0h 0m 0s 33ms
# result2repseq /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_rep --db-load-mode 0 --compressed 0 --threads 8 -v 3
#
# [=================================================================] 100.00% 12.46K 0s 12ms
# Time for merging to clu_rep: 0h 0m 0s 15ms
# Time for processing: 0h 0m 0s 49ms
# result2flat /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_rep /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/rep_seq.fasta --use-fasta-header -v 3
#
# Time for processing: 0h 0m 0s 71ms
# createseqfiledb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_seqs --threads 8 -v 3
#
# [=================================================================] 100.00% 12.46K 0s 14ms                 ] 62.89% 7.84K eta 0s
# Time for merging to clu_seqs: 0h 0m 0s 8ms
# Time for processing: 0h 0m 0s 46ms
# result2flat /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_seqs /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/all_seqs.fasta -v 3
#
# Time for processing: 0h 0m 0s 118ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input -v 3
#
# Time for processing: 0h 0m 0s 2ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/input_h -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_seqs -v 3
#
# Time for processing: 0h 0m 0s 2ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu_rep -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb /var/folders/18/d6ckln_s06q5p3r3knzmkj5w0000gp/T/tmpmi8nv1n4/1896402909476418698/clu -v 3
#
# Time for processing: 0h 0m 0s 1ms

# %%
# Read in the output from mmseqs' easy-cluster
sequence_clusters = read_csv(
    output_file_path + "_cluster.tsv", sep="\t", names=['cluster_representative', 'cluster_component']
)

# %%
# Get some stats on how many representatives and "components" (aka. total num of sequences) are in the set
cluster_representatives = sequence_clusters.cluster_representative.unique()
cluster_components = sequence_clusters.cluster_component.unique()

print(f"There's {len(cluster_representatives)} cluster representatives and "
      f"{len(cluster_components)} sequences in total.")
# Out:
# Theres 12460 cluster representatives and 20386 sequences in total.

# %%
# Split representatives into 80% training, 20% testing sequences
x_train, test = train_test_split(cluster_representatives, test_size=0.2, random_state=11)

# Further split training into 10% validation (e.g. for early stopping) and 90% "true" training sequences
train, validation = train_test_split(x_train, test_size=0.1, random_state=11)

# %%
# Add set and validation info to original TSV file
sequence_clusters['set'] = sequence_clusters.cluster_representative.map(
    lambda x: "train" if x in x_train else "test"
)
sequence_clusters['validation'] = sequence_clusters.cluster_representative.map(
    lambda x: True if x in validation else False
)

# %%
# Re-export TSV file (this time as CSV) containing the set and validation metadata
sequence_clusters.to_csv(data_path / 'sequence_cluster_splits.csv', index=None)
